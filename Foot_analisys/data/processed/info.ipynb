# %%
import pandas as pd

df = pd.read_csv('all_matches.csv')

df.head(100)
# Out:
#           Date               HomeTeam    AwayTeam  FTHG  FTAG FTR    HS    AS  \
# 0   2014-08-08                  Reims    Paris SG   2.0   2.0   D   9.0  16.0
# 1   2014-08-09  Evian Thonon Gaillard        Caen   0.0   3.0   A  10.0  12.0
# 2   2014-08-09                 Bastia   Marseille   3.0   3.0   D  13.0   9.0
# 3   2014-08-09               Guingamp  St Etienne   0.0   2.0   A   6.0   7.0
# 4   2014-08-09                  Lille        Metz   0.0   0.0   D  14.0   2.0
# ..         ...                    ...         ...   ...   ...  ..   ...   ...
# 95  2014-08-30             Leverkusen      Hertha   4.0   2.0   H  21.0   3.0
# 96  2014-08-30                Hamburg   Paderborn   0.0   3.0   A  13.0  15.0
# 97  2014-08-30                   Roma  Fiorentina   2.0   0.0   H  20.0  10.0
# 98  2014-08-31               Freiburg  M'gladbach   0.0   0.0   D  17.0   9.0
# 99  2014-08-31              Tottenham   Liverpool   0.0   3.0   A   7.0  17.0
#
# ...

# %%
df.tail(20)
# Out:
#              Date     HomeTeam        AwayTeam  FTHG  FTAG  FTR    HS    AS  \
# 19821  2025-05-25    Newcastle         Everton   0.0   1.0    A  17.0  14.0
# 19822  2025-05-25   Man United     Aston Villa   2.0   0.0    H  25.0   6.0
# 19823  2025-05-25    Liverpool  Crystal Palace   1.0   1.0    D  14.0   8.0
# 19824  2025-05-25      Ipswich        West Ham   1.0   3.0    A  14.0  10.0
# 19825  2025-05-25       Fulham        Man City   0.0   2.0    A  13.0  20.0
# 19826  2025-05-25       Empoli          Verona   1.0   2.0    A  14.0   5.0
# 19827  2025-05-25        Lazio           Lecce   0.0   1.0    A  26.0   9.0
# 19828  2025-05-25       Girona      Ath Madrid   0.0   4.0    A   2.0  19.0
# 19829  2025-05-25   Villarreal         Sevilla   4.0   2.0    H  12.0  17.0
# 19830  2025-05-25   Ath Bilbao       Barcelona   0.0   3.0    A  10.0  13.0
# 19831  2025-05-25      Venezia        Juventus   2.0   3.0    A  12.0  15.0
# ...

# %%
df_2 = pd.read_csv('train_full_stats_dataset.csv')

# %%
df_2.tail(100)
# Out:
#              Date       HomeTeam   AwayTeam  Home_FTHG_avg  Home_FTAG_avg  \
# 17506  2025-05-11      Liverpool    Arsenal            2.1            1.1
# 17507  2025-05-11      Newcastle    Chelsea            2.5            1.1
# 17508  2025-05-11      Stuttgart   Augsburg            1.3            2.2
# 17509  2025-05-11         Verona      Lecce            0.7            0.6
# 17510  2025-05-11  Ein Frankfurt   St Pauli            1.8            1.0
# ...           ...            ...        ...            ...            ...
# 17601  2025-05-25    Southampton    Arsenal            1.4            1.1
# 17602  2025-05-25      Tottenham   Brighton            2.1            1.1
# 17603  2025-05-25    Bournemouth  Leicester            1.2            1.3
# 17604  2025-05-25         Empoli     Verona            1.2            1.0
# 17605  2025-05-25         Wolves  Brentford            1.6            1.2
#
#        Home_HS_avg  Home_AS_avg  Home_HST_avg  Home_AST_avg  Home_HF_avg  ...  \
# ...
